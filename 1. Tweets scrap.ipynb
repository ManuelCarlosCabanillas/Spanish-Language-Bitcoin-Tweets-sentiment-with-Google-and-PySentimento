# %%
# Run the pip install command below if you don't already have the library
#!pip install git+https://github.com/JustAnotherArchivist/snscrape.git
#!pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Run the below command if you don't already have Pandas
#!pip install pandas

# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd
import time
from tqdm import tqdm

# %%
sntwitter.TwitterSearchScraper('#Bitcoin since:2013-01-01 until:2022-04-10')

# %%
## Búsqueda por texto

#good_users=0
# Setting variables to be used below
maxTweets = 5000000000000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in tqdm(enumerate(sntwitter.TwitterSearchScraper('#Bitcoin since:2013-01-01 until:2022-04-10').get_items())):
    
    #if tweet.likeCount>=0:
    #good_users+=1
    #print(good_users)
    tweets_list2.append([tweet.date, 
                         ])
# Out:
# 17994it [18:49, 19.43it/s]

# %%
tweets_df = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'followersCount',
                         'friendsCount',
                         'replyCount',
                         'retweetCount',
                         'likeCount',
                         'quoteCount', 
                         'retweetedTweetone', 
                         'quotedTweet', 
                         'inReplyToTweetId',
                         'inReplyToUser', 
                         'mentionedUsers'])

# %%
tweets_df
# Out:
#                         Datetime             Tweet Id  \
# 0      2022-03-28 23:59:14+00:00  1508594595936063489
# 1      2022-03-28 23:57:16+00:00  1508594098680311828
# 2      2022-03-28 23:54:16+00:00  1508593343504265220
# 3      2022-03-28 23:53:29+00:00  1508593150205607941
# 4      2022-03-28 23:53:00+00:00  1508593025475178499
# ...                          ...                  ...
# 861637 2020-01-01 00:18:01+00:00  1212166047392026624
# 861638 2020-01-01 00:17:22+00:00  1212165885772935168
# 861639 2020-01-01 00:10:50+00:00  1212164240607498242
# 861640 2020-01-01 00:00:57+00:00  1212161752751845376
# 861641 2020-01-01 00:00:03+00:00  1212161527605858304
#
#                                                      Text         Username  \
# 0       🏝 Isla Satoshi: el próximo lugar favorito de t...   heraldobinario
# 1       Atentos a la corrección de #Bitcoin en 4h. \n\...  NelsonD35864260
# 2       Con Bybit Earn vas a poder aumentar tus activo...   maikelestebenz
# ...

# %%
tweets_df.to_csv('dataset_total_1_20_a_3_22backup.csv')
